# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y = [1,2,3,4],[1,4,2,3]
plt.plot(x,y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[2,3,4,1])

# %%
fig = plt.figure() #an empty figure with no axes

# %%
fig,ax = plt.subplots()

# %%
fig,ax = plt.subplots(2,2)

# %%
fix,ax = plt.subplot_mosaic([['left','right_top'],['left','right_bottom']])

# %%
fix,ax = plt.subplot_mosaic([['left_top','right'],['left_bottom','right']])

# %%
fix,ax = plt.subplot_mosaic([['0','1'],['0','2']])

ax['0'].bar(x,y)
ax['1'].plot(x,y)
ax['2'].hist([10,15,12,13,12,10])
ax['0'].set_title('Age')
# Out:
# Text(0.5, 1.0, 'Age')
