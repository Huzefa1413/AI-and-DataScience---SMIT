# %%
# Import seaborn
import seaborn as sns
import matplotlib.pyplot as plt
# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
plt.show()

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)
plt.show()

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")
plt.show()

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)
plt.show()

# %%
sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker")
plt.show()

# %%
sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True)
plt.show()

# %%
sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker")
plt.show()

# %%
# Load an example dataset
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset from seaborn
titanic_df = sns.load_dataset("titanic")

# Filter the dataset to include only males
males_df = titanic_df[titanic_df["sex"] == "male"]

# Count the number of males who survived and died
survived = males_df[males_df["survived"] == 1].shape[0]
died = males_df[males_df["survived"] == 0].shape[0]

# Create a list of labels
labels = ["Survived", "Died"]

# Create a list of proportions
proportions = [survived, died]

# Create the pie chart
plt.pie(proportions, labels=labels, autopct="%1.1f%%")

# Add a title
plt.title("Proportion of Males Survived and Died")

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset from seaborn
titanic_df = sns.load_dataset("titanic")

# Filter the dataset to include only males
females_df = titanic_df[titanic_df["sex"] == "female"]

# Count the number of males who survived and died
survived = females_df[females_df["survived"] == 1].shape[0]
died = females_df[females_df["survived"] == 0].shape[0]

# Create a list of labels
labels = ["Survived", "Died"]

# Create a list of proportions
proportions = [survived, died]

# Create the pie chart
plt.pie(proportions, labels=labels, autopct="%1.1f%%")

# Add a title
plt.title("Proportion of Females Survived and Died")

# Display the plot
plt.show()

# %%
sns.relplot(
    data=titanic, kind="line",
    x="age", y="fare"
)
plt.show()
